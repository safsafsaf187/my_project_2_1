# %%
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt
import os

DATA_PATH = Path(r"C:\Users\Galin22\.cache\kagglehub\datasets\jehanbhathena\weather-dataset\versions\3\dataset")


# Посмотрим, какие есть классы
classes = [d.name for d in DATA_PATH.iterdir() if d.is_dir()]
print("Классы:", classes)

# Покажем по 1 изображению из каждого класса
fig, axs = plt.subplots(1, len(classes), figsize=(15, 5))
for i, cls in enumerate(classes):
    img_path = next((DATA_PATH / cls).glob("*.jpg"))
    img = Image.open(img_path)
    axs[i].imshow(img)
    axs[i].set_title(cls)
    axs[i].axis('off')

plt.show()
# Out:
# Классы: ['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightning', 'rain', 'rainbow', 'rime', 'sandstorm', 'snow']

# %%
import os
model_path = os.path.join("..", "models", "resnet_weather.pt")
size_mb = os.path.getsize(model_path) / (1024 * 1024)
print(f"Размер модели: {size_mb:.2f} МБ")
# Out:
# Размер модели: 42.73 МБ
